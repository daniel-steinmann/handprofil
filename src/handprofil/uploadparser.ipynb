# %%
import pandas as pd
import numpy as np

# %%
measurement_info = pd.read_excel(
    "download/measurement_template_filled.xlsx",
    header=0,
    skiprows=3,
    nrows=9,
    names=["id","description","value"],
    usecols=[0,1,2],
    dtype= {
            "id": np.int64,
            "device": str,
        }
)
measurement_info
# Out:
#    id   description                value
# 0   1            ID                 MST2
# 1   2         Datum  2023-01-22 00:00:00
# 2   3          Name               Muster
# 3   4       Vorname                  Max
# 4   5  Geburtsdatum  1996-01-10 00:00:00
# 5   6    Geschlecht                    M
# 6   7    Händigkeit                    R
# 7   8    Instrument              Violine

# %%
try:
    measurement_data = pd.read_excel(
        "download/measurement_template_filled.xlsx",
        header=0,
        skiprows=14,
        usecols=[0,1,2,5,6],
        names=["id","device","description","measurement_left","measurement_right"],
        dtype={
            "id": np.int64,
            "device": str,
            "description": str,
            "measurement_left": np.float64,
            "measurement_right": np.float64
        }
    )
except ValueError as e:
    print(e) 
measurement_data
# Out:
#       id      device                                    description  \
# 0      1   Handlabor                                      Handlänge
# 1      2   Handlabor                                     Handbreite
# 2      3   Handlabor                                  Handindex 2:1
# 3      4   Handlabor                               Handgelenkbreite
# 4      5   Handlabor                                Handrückenlänge
# ..   ...         ...                                            ...
# 98   234  Handgelenk              Abduktion ulnar + Flexion, 50 Ncm
# 99   235  Handgelenk           Abduktion radial + Extension, 50 Ncm
# 100  236  Handgelenk  Summe Abduktion + Extension / Flexion, 50 Ncm
# 101  237  Handgelenk                                Extension aktiv
# 102  238  Handgelenk                                  Flexion aktiv
#
#      measurement_left  measurement_right
# 0              194.00             193.00
# 1               86.00              86.00
# 2                0.44               0.44
# 3               58.00              58.00
# 4               99.00              98.00
# ..                ...                ...
# 98                NaN                NaN
# 99                NaN                NaN
# 100               NaN                NaN
# 101               NaN                NaN
# 102               NaN                NaN
#
# [103 rows x 5 columns]

# %%
measurement_data["measurement_left"]
# Out:
# 0      194.00
# 1       86.00
# 2        0.44
# 3       58.00
# 4       99.00
#         ...
# 98        NaN
# 99        NaN
# 100       NaN
# 101       NaN
# 102       NaN
# Name: measurement_left, Length: 103, dtype: float64
